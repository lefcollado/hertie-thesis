# %%
# !pip install pyreadstat
# Out:
# Collecting pyreadstat
#   Downloading pyreadstat-1.3.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: narwhals>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from pyreadstat) (2.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pyreadstat) (2.0.2)
# Downloading pyreadstat-1.3.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 36.9 MB/s eta 0:00:00
# Installing collected packages: pyreadstat
# Successfully installed pyreadstat-1.3.3

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

import pyreadstat
# Out:
# /kaggle/input/datasets/lefcollado/pod-2023/Banco2023_divulgacao_190225.sav
# /kaggle/input/datasets/lefcollado/renda-per-capita-por-zona-od-2023/pod_23_renda-per-capita_tab06.xlsx

# %% [markdown]
# ## Loading data

# %%
pod_23, meta = pyreadstat.read_sav("/kaggle/input/datasets/lefcollado/pod-2023/Banco2023_divulgacao_190225.sav")
pod_23.shape
# Out:
# (143038, 147)

# %%
pod_23.head()
# Out:
#    zona  muni_dom  co_dom_x   co_dom_y    id_dom  f_dom  Fe_dom  dom  \
# 0   1.0      36.0  333725.0  7394554.0              1.0   32.34  1.0
# 1   1.0      36.0  333725.0  7394554.0  00100001    0.0   32.34  1.0
# 2   1.0      36.0  333725.0  7394554.0  00100002    1.0   32.34  2.0
# 3   1.0      36.0  333725.0  7394554.0  00100002    0.0   32.34  2.0
# 4   1.0      36.0  333725.0  7394554.0  00100002    0.0   32.34  2.0
#
#    cd_entre        DATA  ...  duracao modoprin tipvg  tp_esauto  vl_est  \
# 0       1.0  2024-04-17  ...     30.0     16.0   4.0        NaN     NaN
# 1       1.0  2024-04-17  ...     30.0     16.0   4.0        NaN     NaN
# 2       1.0  2024-04-17  ...     30.0     12.0   2.0        NaN     NaN
# 3       1.0  2024-04-17  ...     25.0     12.0   2.0        NaN     NaN
# 4       1.0  2024-04-17  ...     30.0     12.0   2.0        NaN     NaN
#
#    pe_bici  tp_estbici  prop_bici     distancia  id_ordem
# 0      7.0         2.0        1.0   1518.600013       1.0
# 1      9.0         2.0        1.0   1518.600013       2.0
# 2      NaN         NaN        NaN   8350.069281       3.0
# 3      NaN         NaN        NaN   8350.069281       4.0
# 4      NaN         NaN        NaN  10346.375791       5.0
#
# [5 rows x 147 columns]

# %%
type(pod_23)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Creating dictionary
# Creating a list of variables to match the dictionary providaded by Metro

# %%
col23 = list(pod_23.columns)
col23_df = pd.DataFrame(col23, columns=["column_name"])
col23_df.to_excel("pod_23_columns.xlsx", index=False)

# %% [markdown]
# ## First assessment of dataframe

# %%
na_df = pod_23.isna().sum().sort_values(ascending=False).to_frame(name="missing_count")

na_df.to_excel("pod_23_tot_NAs.xlsx")

# %% [markdown]
# ### Creating new dataframe with variables of interest

# %%
pod_23_2 = pod_23[
    [
        "id_ordem",
        "zona",
        "modoprin",
        "distancia",
        "dia_sem",
        "motivo_o",
        "motivo_d",
        "h_saida",
        "idade",
        "sexo",
        "grau_ins",
        "qt_auto",
        "cd_ativi",
        "renda_fa",
        "setor1",
        "vinc1",
    ]
].copy()

# %%
pod_23_2.shape
# Out:
# (143038, 16)

# %%
pod_23_2.head()
# Out:
#    id_ordem  zona  modoprin     distancia  dia_sem  motivo_o  motivo_d  \
# 0       1.0   1.0      16.0   1518.600013      3.0       8.0       2.0
# 1       2.0   1.0      16.0   1518.600013      3.0       2.0       8.0
# 2       3.0   1.0      12.0   8350.069281      3.0       8.0       7.0
# 3       4.0   1.0      12.0   8350.069281      3.0       7.0       8.0
# 4       5.0   1.0      12.0  10346.375791      3.0       8.0       7.0
#
#    h_saida  idade  sexo  grau_ins  qt_auto  cd_ativi  renda_fa  setor1  vinc1
# 0     11.0   67.0   1.0       4.0      1.0       4.0    7000.0     9.0    6.0
# 1     15.0   67.0   1.0       4.0      1.0       4.0    7000.0     9.0    6.0
# 2     18.0   22.0   2.0       3.0      0.0       1.0   10000.0     4.0    6.0
# 3     23.0   22.0   2.0       3.0      0.0       1.0   10000.0     4.0    6.0
# 4     13.0   21.0   2.0       3.0      0.0       1.0   10000.0     4.0    6.0

# %% [markdown]
# NA count in each column

# %%
pod_23_2.isna().sum()
# Out:
# id_ordem         0
# zona             0
# modoprin     30125
# distancia    30125
# dia_sem      30125
# motivo_o     30125
# motivo_d     30125
# h_saida      30125
# idade            0
# sexo             0
# grau_ins         0
# qt_auto        179
# cd_ativi         0
# renda_fa         0
# setor1       63696
# vinc1        63696
# dtype: int64

# %% [markdown]
# ### New dataframe without NAs in the column 'Main mode of transport'"

# %%
pod_23_2 = pod_23_2[pod_23_2["modoprin"].notna()].copy()

# %%
pod_23_2.isna().sum()
# Out:
# id_ordem         0
# zona             0
# modoprin         0
# distancia        0
# dia_sem          0
# motivo_o         0
# motivo_d         0
# h_saida          0
# idade            0
# sexo             0
# grau_ins         0
# qt_auto        110
# cd_ativi         0
# renda_fa         0
# setor1       43538
# vinc1        43538
# dtype: int64

# %%
pod_23_2.shape
# Out:
# (112913, 16)

# %% [markdown]
# ## Cleaning and formatting specific columns

# %% [markdown]
# ### Quantity of cars per household
#
# !!! o que fazer com os NAs??

# %%
pod_23_2["qt_auto"].value_counts(dropna=False)
# Out:
# qt_auto
# 1.0    55889
# 0.0    39476
# 2.0    14721
# 3.0     2229
# 4.0      415
# NaN      110
# 5.0       37
# 9.0       22
# 6.0       14
# Name: count, dtype: int64

# %% [markdown]
# ### Creating target variable

# %%
pod_23_2["modoprin"].value_counts(dropna=False)
# Out:
# modoprin
# 17.0    29962
# 9.0     27771
# 4.0     12466
# 1.0      9367
# 10.0     8567
# 8.0      5930
# 12.0     4229
# 6.0      3848
# 13.0     3015
# 5.0      2494
# 2.0      2479
# 16.0      970
# 7.0       741
# 11.0      485
# 14.0      276
# 18.0      208
# 3.0        81
# 15.0       24
# Name: count, dtype: int64

# %%
pod_23_2["modoprin_y"] = pod_23_2["modoprin"].isin([16, 17]).astype(int)

# %%
pod_23_2["modoprin_y"].value_counts(dropna=False)
# Out:
# modoprin_y
# 0    81981
# 1    30932
# Name: count, dtype: int64

# %% [markdown]
# ### Reason for the trip

# %%
pod_23_2["motivo_o"].value_counts(dropna=False)
# Out:
# motivo_o
# 8.0     54086
# 3.0     18747
# 4.0     18082
# 2.0      5266
# 1.0      3417
# 5.0      3206
# 6.0      3171
# 10.0     3124
# 7.0      2762
# 11.0      955
# 9.0        97
# Name: count, dtype: int64

# %% [markdown]
# Transform motivo_o and motivo_d into categorical variable with labels

# %%
motivo_labels = {
    1: "Trabalho Indústria",
    2: "Trabalho Comércio",
    3: "Trabalho Serviços",
    4: "Escola/Educação",
    5: "Compras",
    6: "Médico/Dentista/Saúde",
    7: "Recreação/Visitas/Lazer",
    8: "Residência",
    9: "Procurar Emprego",
    10: "Assuntos Pessoais",
    11: "Refeição"
}

pod_23_2["motivo_o_cat"] = pd.Categorical(
    pod_23_2["motivo_o"].map(motivo_labels),
    categories=list(motivo_labels.values())
)

pod_23_2["motivo_o_cat"].value_counts(dropna=False)
# Out:
# motivo_o_cat
# Residência                 54086
# Trabalho Serviços          18747
# Escola/Educação            18082
# Trabalho Comércio           5266
# Trabalho Indústria          3417
# Compras                     3206
# Médico/Dentista/Saúde       3171
# Assuntos Pessoais           3124
# Recreação/Visitas/Lazer     2762
# Refeição                     955
# Procurar Emprego              97
# Name: count, dtype: int64

# %%
pod_23_2["motivo_d_cat"] = pd.Categorical(
    pod_23_2["motivo_d"].map(motivo_labels),
    categories=list(motivo_labels.values())
)

pod_23_2["motivo_d_cat"].value_counts()
# Out:
# motivo_d_cat
# Residência                 53837
# Trabalho Serviços          18834
# Escola/Educação            18116
# Trabalho Comércio           5286
# Trabalho Indústria          3511
# Compras                     3210
# Médico/Dentista/Saúde       3170
# Assuntos Pessoais           3050
# Recreação/Visitas/Lazer     2857
# Refeição                     944
# Procurar Emprego              98
# Name: count, dtype: int64

# %% [markdown]
# #### Grouping categories

# %%
pod_23_2["motivo_o_group"] = pod_23_2["motivo_o_cat"].map({
    "Residência": "Home",
    
    "Trabalho Serviços": "Work",
    "Trabalho Comércio": "Work",
    "Trabalho Indústria": "Work",
    
    "Escola/Educação": "Education",
    
    "Assuntos Pessoais": "Personal Matters",
    "Compras": "Personal Matters",
    "Refeição": "Personal Matters",
    "Procurar Emprego": "Personal Matters",
    "Recreação/Visitas/Lazer": "Personal Matters",
    "Médico/Dentista/Saúde": "Personal Matters"
})

# %%
pod_23_2["motivo_o_group"] = pd.Categorical(
    pod_23_2["motivo_o_group"],
    categories=["Home", "Work", "Education", "Personal Matters"]
)

# %%
pod_23_2["motivo_o_group"].value_counts(dropna=False)
# Out:
# motivo_o_group
# Home                54086
# Work                27430
# Education           18082
# Personal Matters    13315
# Name: count, dtype: int64

# %%
pod_23_2["motivo_d_group"] = pod_23_2["motivo_d_cat"].map({
    "Residência": "Home",
    
    "Trabalho Serviços": "Work",
    "Trabalho Comércio": "Work",
    "Trabalho Indústria": "Work",
    
    "Escola/Educação": "Education",
    
    "Assuntos Pessoais": "Personal Matters",
    "Compras": "Personal Matters",
    "Refeição": "Personal Matters",
    "Procurar Emprego": "Personal Matters",
    "Recreação/Visitas/Lazer": "Personal Matters",
    "Médico/Dentista/Saúde": "Personal Matters"
})

# %%
pod_23_2["motivo_d_group"] = pd.Categorical(
    pod_23_2["motivo_d_group"],
    categories=["Home", "Work", "Education", "Personal Matters"]
)

# %%
pod_23_2["motivo_d_group"].value_counts()
# Out:
# motivo_d_group
# Home                53837
# Work                27631
# Education           18116
# Personal Matters    13329
# Name: count, dtype: int64

# %%
pod_23_2["motivo_d_group"].dtype
# Out:
# CategoricalDtype(categories=['Home', 'Work', 'Education', 'Personal Matters'], ordered=False, categories_dtype=object)

# %% [markdown]
# #### Join the two columns

# %%
pod_23_2["motivo"] = pod_23_2.apply(
    lambda row:
        "Home - Work"
        if {str(row["motivo_o_group"]), str(row["motivo_d_group"])} == {"Home", "Work"}
        else "Home - Personal Matters"
        if {str(row["motivo_o_group"]), str(row["motivo_d_group"])} == {"Home", "Personal Matters"}
        else "Home - Education"
        if {str(row["motivo_o_group"]), str(row["motivo_d_group"])} == {"Home", "Education"}
        else "Others",
    axis=1
)

pod_23_2["motivo"].value_counts(dropna=False)
# Out:
# motivo
# Home - Work                50955
# Home - Education           34059
# Home - Personal Matters    22909
# Others                      4990
# Name: count, dtype: int64

# %% [markdown]
# ### Level of education

# %%
grau_labels = {
    1: "No Formal Education/Incomplete Primary Education",
    2: "Primary Education Completed / Lower Secondary Incomplete",
    3: "Lower Secondary Completed / Upper Secondary Incomplete",
    4: "Upper Secondary Completed / Higher Education Incomplete",
    5: "Higher Education Completed"
}

pod_23_2["grau_ins"] = pd.Categorical(
    pod_23_2["grau_ins"].map(grau_labels),
    categories=list(grau_labels.values()),
    ordered=True
)

pod_23_2["grau_ins"].value_counts()
# Out:
# grau_ins
# Upper Secondary Completed / Higher Education Incomplete     38060
# Higher Education Completed                                  34967
# No Formal Education/Incomplete Primary Education            14209
# Lower Secondary Completed / Upper Secondary Incomplete      13443
# Primary Education Completed / Lower Secondary Incomplete    12234
# Name: count, dtype: int64

# %% [markdown]
# ### Currently working?

# %%
pod_23_2["cd_ativi"].value_counts(dropna=False)
# Out:
# cd_ativi
# 1.0    66240
# 8.0    20018
# 4.0    11014
# 5.0     4942
# 7.0     4041
# 6.0     3816
# 2.0     2654
# 3.0      188
# Name: count, dtype: int64

# %%
pod_23_2["curr_work"] = (pod_23_2["cd_ativi"] == 1).astype(int)
pod_23_2["curr_work"].value_counts()
# Out:
# curr_work
# 1    66240
# 0    46673
# Name: count, dtype: int64

# %% [markdown]
# ### Days of the week

# %%
pod_23_2["dia_sem"].value_counts()
# Out:
# dia_sem
# 6.0    34125
# 3.0    26811
# 2.0    20814
# 4.0    16348
# 5.0    14814
# 0.0        1
# Name: count, dtype: int64

# %%
day_labels = {
    2: "Monday",
    3: "Tuesday",
    4: "Wednesday",
    5: "Thursday",
    6: "Friday"
}

pod_23_2["dia_sem"] = pd.Categorical(
    pod_23_2["dia_sem"].map(day_labels),
    categories=list(day_labels.values()),
    ordered=True
)

pod_23_2["dia_sem"].value_counts(dropna=False)
# Out:
# dia_sem
# Friday       34125
# Tuesday      26811
# Monday       20814
# Wednesday    16348
# Thursday     14814
# NaN              1
# Name: count, dtype: int64

# %%
pod_23_2 = pod_23_2[pod_23_2["dia_sem"].notna()].copy()

# %%
pod_23_2["dia_sem"].value_counts(dropna=False)
# Out:
# dia_sem
# Friday       34125
# Tuesday      26811
# Monday       20814
# Wednesday    16348
# Thursday     14814
# Name: count, dtype: int64

# %% [markdown]
# ### Time of day of trip start

# %%
pod_23_2["h_saida"].dtype
# Out:
# dtype('float64')

# %%
pod_23_2["h_saida"].head()
# Out:
# 0    11.0
# 1    15.0
# 2    18.0
# 3    23.0
# 4    13.0
# Name: h_saida, dtype: float64

# %%
pod_23_2["h_saida"].describe()
# Out:
# count    112912.000000
# mean         12.444443
# std           4.927284
# min           0.000000
# 25%           8.000000
# 50%          12.000000
# 75%          17.000000
# max          23.000000
# Name: h_saida, dtype: float64

# %%
pod_23_2["h_saida_period"] = pd.cut(
    pod_23_2["h_saida"],
    bins=[0, 5, 10, 13, 18, 24],
    labels=["Dawn", "Morning", "Lunch", "Afternoon", "Night"],
    include_lowest=True,
    right=True
)

pod_23_2["h_saida_period"].value_counts()
# Out:
# h_saida_period
# Morning      37698
# Afternoon    36393
# Lunch        23779
# Night        10811
# Dawn          4231
# Name: count, dtype: int64

# %% [markdown]
# ### In which sector is your main occupation?

# %%
pod_23_2["setor1"].value_counts(dropna=False)
# Out:
# setor1
# NaN     43538
# 4.0     13649
# 14.0    10921
# 12.0    10150
# 3.0      6690
# 10.0     6492
# 11.0     4874
# 2.0      3435
# 9.0      2902
# 8.0      2318
# 7.0      2201
# 13.0     2151
# 6.0      1845
# 5.0      1629
# 1.0       117
# Name: count, dtype: int64

# %%
sector_map = {
    1: "Agriculture",
    2: "Construction",
    3: "Industry",
    4: "Commerce",
    13: "Public Administration"
}

pod_23_2["sector_comb"] = pod_23_2["setor1"].map(sector_map)

pod_23_2["sector_comb"] = pod_23_2["sector_comb"].mask(
    pod_23_2["sector_comb"].isna() & pod_23_2["setor1"].notna(),
    "Services"
)

pod_23_2["sector_comb"].value_counts(dropna=False)
# Out:
# sector_comb
# NaN                      43538
# Services                 43332
# Commerce                 13649
# Industry                  6690
# Construction              3435
# Public Administration     2151
# Agriculture                117
# Name: count, dtype: int64

# %% [markdown]
# ### Emplyment relationship

# %%
pod_23_2["vinc1"].value_counts(dropna=False)
# Out:
# vinc1
# NaN    43538
# 1.0    37493
# 6.0    10501
# 5.0     9456
# 2.0     3640
# 3.0     3316
# 4.0     2383
# 7.0     1290
# 8.0     1055
# 9.0      240
# Name: count, dtype: int64

# %%
empl_map = {
    1: "Wage and salaried employees",
    2: "Wage and salaried employees",
    3: "Public sector",
    5: "Self-employed",
    6: "Self-employed"
}

pod_23_2["empl_relat"] = pod_23_2["vinc1"].map(empl_map)

pod_23_2["empl_relat"] = pod_23_2["empl_relat"].mask(
    pod_23_2["empl_relat"].isna() & pod_23_2["vinc1"].notna(),
    "Other"
)

pod_23_2["empl_relat"].value_counts(dropna=False)
# Out:
# empl_relat
# NaN                            43538
# Wage and salaried employees    41133
# Self-employed                  19957
# Other                           4968
# Public sector                   3316
# Name: count, dtype: int64

# %% [markdown]
# ### Gender

# %%
pod_23_2["sexo"].value_counts(dropna=False)
# Out:
# sexo
# 2.0    56747
# 1.0    56123
# 3.0       42
# Name: count, dtype: int64

# %%
pod_23_2["gender"] = pod_23_2["sexo"].map({
    1: "Male",
    2: "Female"
})

pod_23_2["gender"].value_counts(dropna=False)
# Out:
# gender
# Female    56747
# Male      56123
# NaN          42
# Name: count, dtype: int64

# %%
pod_23_2 = pod_23_2[pod_23_2["gender"].notna()].copy()

pod_23_2["gender"].value_counts(dropna=False)
# Out:
# gender
# Female    56747
# Male      56123
# Name: count, dtype: int64

# %% [markdown]
# ## Adding external data for income per capita in the zone of home address

# %%
renda_zona = pd.read_excel(
    "/kaggle/input/datasets/lefcollado/renda-per-capita-por-zona-od-2023/pod_23_renda-per-capita_tab06.xlsx"
)

pod_23_2 = pod_23_2.merge(
    renda_zona[["zona", "renda_pc"]],
    on="zona",
    how="left"
).rename(columns={"renda_pc": "pc_income"})

pod_23_2[["zona", "pc_income"]].head()
# Out:
#    zona    pc_income
# 0   1.0  2309.022764
# 1   1.0  2309.022764
# 2   1.0  2309.022764
# 3   1.0  2309.022764
# 4   1.0  2309.022764

# %%
pod_23_2["pc_income"].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Age intervals

# %%
pod_23_2["age"] = pd.cut(
    pod_23_2["idade"],
    bins=[-float("inf"), 15, 29, 59, float("inf")],
    labels=[
        "15 years old or less",
        "16 to 29 years old",
        "30 to 59 years old",
        "60 years old or older"
    ]
)

pod_23_2["age"].value_counts(dropna=False)
# Out:
# age
# 30 to 59 years old       53588
# 16 to 29 years old       22793
# 60 years old or older    18304
# 15 years old or less     18185
# Name: count, dtype: int64

# %%
pod_23_2.loc[pod_23_2["idade"] <= 15, "idade"].value_counts(dropna=False).sort_index()
# Out:
# idade
# 1.0      574
# 2.0      501
# 3.0      728
# 4.0     1024
# 5.0     1166
# 6.0     1347
# 7.0     1270
# 8.0     1369
# 9.0     1348
# 10.0    1440
# 11.0    1221
# 12.0    1465
# 13.0    1495
# 14.0    1510
# 15.0    1727
# Name: count, dtype: int64

# %% [markdown]
# ## Creating new dataframe with constructed variables

# %%
summary = pd.DataFrame({
    "column": pod_23_2.columns,
    "dtype": pod_23_2.dtypes.values,
    "na_count": pod_23_2.isna().sum().values
})

# Function to get categories / unique values (limited for readability)
def get_values(col):
    if isinstance(col.dtype, pd.CategoricalDtype):
        return ", ".join(map(str, col.cat.categories))
    elif col.nunique() <= 10:
        return ", ".join(map(str, col.dropna().unique()))
    else:
        return "—"

summary["possible_values"] = [
    get_values(pod_23_2[col]) for col in pod_23_2.columns
]

summary.style.set_properties(**{"text-align": "left"})
# Out:
# <style type="text/css">
# #T_71cc5_row0_col0, #T_71cc5_row0_col1, #T_71cc5_row0_col2, #T_71cc5_row0_col3, #T_71cc5_row1_col0, #T_71cc5_row1_col1, #T_71cc5_row1_col2, #T_71cc5_row1_col3, #T_71cc5_row2_col0, #T_71cc5_row2_col1, #T_71cc5_row2_col2, #T_71cc5_row2_col3, #T_71cc5_row3_col0, #T_71cc5_row3_col1, #T_71cc5_row3_col2, #T_71cc5_row3_col3, #T_71cc5_row4_col0, #T_71cc5_row4_col1, #T_71cc5_row4_col2, #T_71cc5_row4_col3, #T_71cc5_row5_col0, #T_71cc5_row5_col1, #T_71cc5_row5_col2, #T_71cc5_row5_col3, #T_71cc5_row6_col0, #T_71cc5_row6_col1, #T_71cc5_row6_col2, #T_71cc5_row6_col3, #T_71cc5_row7_col0, #T_71cc5_row7_col1, #T_71cc5_row7_col2, #T_71cc5_row7_col3, #T_71cc5_row8_col0, #T_71cc5_row8_col1, #T_71cc5_row8_col2, #T_71cc5_row8_col3, #T_71cc5_row9_col0, #T_71cc5_row9_col1, #T_71cc5_row9_col2, #T_71cc5_row9_col3, #T_71cc5_row10_col0, #T_71cc5_row10_col1, #T_71cc5_row10_col2, #T_71cc5_row10_col3, #T_71cc5_row11_col0, #T_71cc5_row11_col1, #T_71cc5_row11_col2, #T_71cc5_row11_col3, #T_71cc5_row12_col0, #T_71cc5_row12_col1, #T_71cc5_row12_col2, #T_71cc5_row12_col3, #T_71cc5_row13_col0, #T_71cc5_row13_col1, #T_71cc5_row13_col2, #T_71cc5_row13_col3, #T_71cc5_row14_col0, #T_71cc5_row14_col1, #T_71cc5_row14_col2, #T_71cc5_row14_col3, #T_71cc5_row15_col0, #T_71cc5_row15_col1, #T_71cc5_row15_col2, #T_71cc5_row15_col3, #T_71cc5_row16_col0, #T_71cc5_row16_col1, #T_71cc5_row16_col2, #T_71cc5_row16_col3, #T_71cc5_row17_col0, #T_71cc5_row17_col1, #T_71cc5_row17_col2, #T_71cc5_row17_col3, #T_71cc5_row18_col0, #T_71cc5_row18_col1, #T_71cc5_row18_col2, #T_71cc5_row18_col3, #T_71cc5_row19_col0, #T_71cc5_row19_col1, #T_71cc5_row19_col2, #T_71cc5_row19_col3, #T_71cc5_row20_col0, #T_71cc5_row20_col1, #T_71cc5_row20_col2, #T_71cc5_row20_col3, #T_71cc5_row21_col0, #T_71cc5_row21_col1, #T_71cc5_row21_col2, #T_71cc5_row21_col3, #T_71cc5_row22_col0, #T_71cc5_row22_col1, #T_71cc5_row22_col2, #T_71cc5_row22_col3, #T_71cc5_row23_col0, #T_71cc5_row23_col1, #T_71cc5_row23_col2, #T_71cc5_row23_col3, #T_71cc5_row24_col0, #T_71cc5_row24_col1, #T_71cc5_row24_col2, #T_71cc5_row24_col3, #T_71cc5_row25_col0, #T_71cc5_row25_col1, #T_71cc5_row25_col2, #T_71cc5_row25_col3, #T_71cc5_row26_col0, #T_71cc5_row26_col1, #T_71cc5_row26_col2, #T_71cc5_row26_col3, #T_71cc5_row27_col0, #T_71cc5_row27_col1, #T_71cc5_row27_col2, #T_71cc5_row27_col3, #T_71cc5_row28_col0, #T_71cc5_row28_col1, #T_71cc5_row28_col2, #T_71cc5_row28_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_71cc5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71cc5_level0_col0" class="col_heading level0 col0" >column</th>
#       <th id="T_71cc5_level0_col1" class="col_heading level0 col1" >dtype</th>
#       <th id="T_71cc5_level0_col2" class="col_heading level0 col2" >na_count</th>
#       <th id="T_71cc5_level0_col3" class="col_heading level0 col3" >possible_values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71cc5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_71cc5_row0_col0" class="data row0 col0" >id_ordem</td>
#       <td id="T_71cc5_row0_col1" class="data row0 col1" >float64</td>
#       <td id="T_71cc5_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_71cc5_row0_col3" class="data row0 col3" >—</td>
#     </tr>
#     <tr>
#       <th id="T_71cc5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_71cc5_row1_col0" class="data row1 col0" >zona</td>
#       <td id="T_71cc5_row1_col1" class="data row1 col1" >float64</td>
#       <td id="T_71cc5_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_71cc5_row1_col3" class="data row1 col3" >—</td>
#     </tr>
#     <tr>
#       <th id="T_71cc5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_71cc5_row2_col0" class="data row2 col0" >modoprin</td>
#       <td id="T_71cc5_row2_col1" class="data row2 col1" >float64</td>
#       <td id="T_71cc5_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_71cc5_row2_col3" class="data row2 col3" >—</td>
#     </tr>
#     <tr>
#       <th id="T_71cc5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_71cc5_row3_col0" class="data row3 col0" >distancia</td>
#       <td id="T_71cc5_row3_col1" class="data row3 col1" >float64</td>
#       <td id="T_71cc5_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_71cc5_row3_col3" class="data row3 col3" >—</td>
#     </tr>
#     <tr>
#       <th id="T_71cc5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_71cc5_row4_col0" class="data row4 col0" >dia_sem</td>
#       <td id="T_71cc5_row4_col1" class="data row4 col1" >category</td>
#       <td id="T_71cc5_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_71cc5_row4_col3" class="data row4 col3" >Monday, Tuesday, Wednesday, Thursday, Friday</td>
#     </tr>
#     <tr>
#       <th id="T_71cc5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_71cc5_row5_col0" class="data row5 col0" >motivo_o</td>
#       <td id="T_71cc5_row5_col1" class="data row5 col1" >float64</td>
#       <td id="T_71cc5_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_71cc5_row5_col3" class="data row5 col3" >—</td>
#     </tr>
#     <tr>
#       <th id="T_71cc5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_71cc5_row6_col0" class="data row6 col0" >motivo_d</td>
#       <td id="T_71cc5_row6_col1" class="data row6 col1" >float64</td>
#       <td id="T_71cc5_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_71cc5_row6_col3" class="data row6 col3" >—</td>
#     </tr>
#     <tr>
#       <th id="T_71cc5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_71cc5_row7_col0" class="data row7 col0" >h_saida</td>
#       <td id="T_71cc5_row7_col1" class="data row7 col1" >float64</td>
#       <td id="T_71cc5_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_71cc5_row7_col3" class="data row7 col3" >—</td>
#     </tr>
#     <tr>
#       <th id="T_71cc5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_71cc5_row8_col0" class="data row8 col0" >idade</td>
#       <td id="T_71cc5_row8_col1" class="data row8 col1" >float64</td>
#       <td id="T_71cc5_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_71cc5_row8_col3" class="data row8 col3" >—</td>
#     </tr>
#     <tr>
#       <th id="T_71cc5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_71cc5_row9_col0" class="data row9 col0" >sexo</td>
#       <td id="T_71cc5_row9_col1" class="data row9 col1" >float64</td>
#       <td id="T_71cc5_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_71cc5_row9_col3" class="data row9 col3" >1.0, 2.0</td>
#     </tr>
#     <tr>
#       <th id="T_71cc5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_71cc5_row10_col0" class="data row10 col0" >grau_ins</td>
#       <td id="T_71cc5_row10_col1" class="data row10 col1" >category</td>
#       <td id="T_71cc5_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_71cc5_row10_col3" class="data row10 col3" >No Formal Education/Incomplete Primary Education, Primary Education Completed / Lower Secondary Incomplete, Lower Secondary Completed / Upper Secondary Incomplete, Upper Secondary Completed / Higher Education Incomplete, Higher Education Completed</td>
#     </tr>
#     <tr>
#       <th id="T_71cc5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_71cc5_row11_col0" class="data row11 col0" >qt_auto</td>
#       <td id="T_71cc5_row11_col1" class="data row11 col1" >float64</td>
#       <td id="T_71cc5_row11_col2" class="data row11 col2" >110</td>
#       <td id="T_71cc5_row11_col3" class="data row11 col3" >1.0, 0.0, 2.0, 3.0, 5.0, 4.0, 9.0, 6.0</td>
#     </tr>
#     <tr>
#       <th id="T_71cc5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_71cc5_row12_col0" class="data row12 col0" >cd_ativi</td>
#       <td id="T_71cc5_row12_col1" class="data row12 col1" >float64</td>
#       <td id="T_71cc5_row12_col2" class="data row12 col2" >0</td>
#       <td id="T_71cc5_row12_col3" class="data row12 col3" >4.0, 1.0, 8.0, 7.0, 6.0, 5.0, 2.0, 3.0</td>

# %%
pod_23_3 = pod_23_2[
    [
        "id_ordem",
        "zona",
        "modoprin_y",
        "distancia",
        "age",
        "gender",
        "grau_ins",
        "renda_fa",
        "pc_income",
        "qt_auto",
        "motivo",
        "h_saida_period",
        "dia_sem",
        "curr_work",
        "sector_comb",
        "empl_relat"
    ]
].copy()

# %%
pod_23_3.shape
# Out:
# (112870, 16)

# %%
pod_23_3.head()
# Out:
#    id_ordem  zona  modoprin_y     distancia                    age  gender  \
# 0       1.0   1.0           1   1518.600013  60 years old or older    Male
# 1       2.0   1.0           1   1518.600013  60 years old or older    Male
# 2       3.0   1.0           0   8350.069281     16 to 29 years old  Female
# 3       4.0   1.0           0   8350.069281     16 to 29 years old  Female
# 4       5.0   1.0           0  10346.375791     16 to 29 years old  Female
#
#                                             grau_ins  renda_fa    pc_income  \
# 0  Upper Secondary Completed / Higher Education I...    7000.0  2309.022764
# 1  Upper Secondary Completed / Higher Education I...    7000.0  2309.022764
# 2  Lower Secondary Completed / Upper Secondary In...   10000.0  2309.022764
# 3  Lower Secondary Completed / Upper Secondary In...   10000.0  2309.022764
# 4  Lower Secondary Completed / Upper Secondary In...   10000.0  2309.022764
#
#    qt_auto                   motivo h_saida_period  dia_sem  curr_work  \
# 0      1.0              Home - Work          Lunch  Tuesday          0
# 1      1.0              Home - Work      Afternoon  Tuesday          0
# 2      0.0  Home - Personal Matters      Afternoon  Tuesday          1
# 3      0.0  Home - Personal Matters          Night  Tuesday          1
# 4      0.0  Home - Personal Matters          Lunch  Tuesday          1
#
#   sector_comb     empl_relat
# 0    Services  Self-employed
# 1    Services  Self-employed
# 2    Commerce  Self-employed
# 3    Commerce  Self-employed
# 4    Commerce  Self-employed

# %%
summary = pd.DataFrame({
    "column": pod_23_3.columns,
    "dtype": pod_23_3.dtypes.values,
    "na_count": pod_23_3.isna().sum().values
})

# Function to get categories / unique values (limited for readability)
def get_values(col):
    if isinstance(col.dtype, pd.CategoricalDtype):
        return ", ".join(map(str, col.cat.categories))
    elif col.nunique() <= 10:
        return ", ".join(map(str, col.dropna().unique()))
    else:
        return "—"

summary["possible_values"] = [
    get_values(pod_23_3[col]) for col in pod_23_3.columns
]

summary.style.set_properties(**{"text-align": "left"})
# Out:
# <style type="text/css">
# #T_9506d_row0_col0, #T_9506d_row0_col1, #T_9506d_row0_col2, #T_9506d_row0_col3, #T_9506d_row1_col0, #T_9506d_row1_col1, #T_9506d_row1_col2, #T_9506d_row1_col3, #T_9506d_row2_col0, #T_9506d_row2_col1, #T_9506d_row2_col2, #T_9506d_row2_col3, #T_9506d_row3_col0, #T_9506d_row3_col1, #T_9506d_row3_col2, #T_9506d_row3_col3, #T_9506d_row4_col0, #T_9506d_row4_col1, #T_9506d_row4_col2, #T_9506d_row4_col3, #T_9506d_row5_col0, #T_9506d_row5_col1, #T_9506d_row5_col2, #T_9506d_row5_col3, #T_9506d_row6_col0, #T_9506d_row6_col1, #T_9506d_row6_col2, #T_9506d_row6_col3, #T_9506d_row7_col0, #T_9506d_row7_col1, #T_9506d_row7_col2, #T_9506d_row7_col3, #T_9506d_row8_col0, #T_9506d_row8_col1, #T_9506d_row8_col2, #T_9506d_row8_col3, #T_9506d_row9_col0, #T_9506d_row9_col1, #T_9506d_row9_col2, #T_9506d_row9_col3, #T_9506d_row10_col0, #T_9506d_row10_col1, #T_9506d_row10_col2, #T_9506d_row10_col3, #T_9506d_row11_col0, #T_9506d_row11_col1, #T_9506d_row11_col2, #T_9506d_row11_col3, #T_9506d_row12_col0, #T_9506d_row12_col1, #T_9506d_row12_col2, #T_9506d_row12_col3, #T_9506d_row13_col0, #T_9506d_row13_col1, #T_9506d_row13_col2, #T_9506d_row13_col3, #T_9506d_row14_col0, #T_9506d_row14_col1, #T_9506d_row14_col2, #T_9506d_row14_col3, #T_9506d_row15_col0, #T_9506d_row15_col1, #T_9506d_row15_col2, #T_9506d_row15_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_9506d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9506d_level0_col0" class="col_heading level0 col0" >column</th>
#       <th id="T_9506d_level0_col1" class="col_heading level0 col1" >dtype</th>
#       <th id="T_9506d_level0_col2" class="col_heading level0 col2" >na_count</th>
#       <th id="T_9506d_level0_col3" class="col_heading level0 col3" >possible_values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9506d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9506d_row0_col0" class="data row0 col0" >id_ordem</td>
#       <td id="T_9506d_row0_col1" class="data row0 col1" >float64</td>
#       <td id="T_9506d_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_9506d_row0_col3" class="data row0 col3" >—</td>
#     </tr>
#     <tr>
#       <th id="T_9506d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9506d_row1_col0" class="data row1 col0" >zona</td>
#       <td id="T_9506d_row1_col1" class="data row1 col1" >float64</td>
#       <td id="T_9506d_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_9506d_row1_col3" class="data row1 col3" >—</td>
#     </tr>
#     <tr>
#       <th id="T_9506d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9506d_row2_col0" class="data row2 col0" >modoprin_y</td>
#       <td id="T_9506d_row2_col1" class="data row2 col1" >int64</td>
#       <td id="T_9506d_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_9506d_row2_col3" class="data row2 col3" >1, 0</td>
#     </tr>
#     <tr>
#       <th id="T_9506d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9506d_row3_col0" class="data row3 col0" >distancia</td>
#       <td id="T_9506d_row3_col1" class="data row3 col1" >float64</td>
#       <td id="T_9506d_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_9506d_row3_col3" class="data row3 col3" >—</td>
#     </tr>
#     <tr>
#       <th id="T_9506d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9506d_row4_col0" class="data row4 col0" >age</td>
#       <td id="T_9506d_row4_col1" class="data row4 col1" >category</td>
#       <td id="T_9506d_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_9506d_row4_col3" class="data row4 col3" >15 years old or less, 16 to 29 years old, 30 to 59 years old, 60 years old or older</td>
#     </tr>
#     <tr>
#       <th id="T_9506d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9506d_row5_col0" class="data row5 col0" >gender</td>
#       <td id="T_9506d_row5_col1" class="data row5 col1" >object</td>
#       <td id="T_9506d_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_9506d_row5_col3" class="data row5 col3" >Male, Female</td>
#     </tr>
#     <tr>
#       <th id="T_9506d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9506d_row6_col0" class="data row6 col0" >grau_ins</td>
#       <td id="T_9506d_row6_col1" class="data row6 col1" >category</td>
#       <td id="T_9506d_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_9506d_row6_col3" class="data row6 col3" >No Formal Education/Incomplete Primary Education, Primary Education Completed / Lower Secondary Incomplete, Lower Secondary Completed / Upper Secondary Incomplete, Upper Secondary Completed / Higher Education Incomplete, Higher Education Completed</td>
#     </tr>
#     <tr>
#       <th id="T_9506d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9506d_row7_col0" class="data row7 col0" >renda_fa</td>
#       <td id="T_9506d_row7_col1" class="data row7 col1" >float64</td>
#       <td id="T_9506d_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_9506d_row7_col3" class="data row7 col3" >—</td>
#     </tr>
#     <tr>
#       <th id="T_9506d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9506d_row8_col0" class="data row8 col0" >pc_income</td>
#       <td id="T_9506d_row8_col1" class="data row8 col1" >float64</td>
#       <td id="T_9506d_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_9506d_row8_col3" class="data row8 col3" >—</td>
#     </tr>
#     <tr>
#       <th id="T_9506d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9506d_row9_col0" class="data row9 col0" >qt_auto</td>
#       <td id="T_9506d_row9_col1" class="data row9 col1" >float64</td>
#       <td id="T_9506d_row9_col2" class="data row9 col2" >110</td>
#       <td id="T_9506d_row9_col3" class="data row9 col3" >1.0, 0.0, 2.0, 3.0, 5.0, 4.0, 9.0, 6.0</td>
#     </tr>
#     <tr>
#       <th id="T_9506d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9506d_row10_col0" class="data row10 col0" >motivo</td>
#       <td id="T_9506d_row10_col1" class="data row10 col1" >object</td>
#       <td id="T_9506d_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_9506d_row10_col3" class="data row10 col3" >Home - Work, Home - Personal Matters, Others, Home - Education</td>
#     </tr>
#     <tr>
#       <th id="T_9506d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9506d_row11_col0" class="data row11 col0" >h_saida_period</td>
#       <td id="T_9506d_row11_col1" class="data row11 col1" >category</td>
#       <td id="T_9506d_row11_col2" class="data row11 col2" >0</td>
#       <td id="T_9506d_row11_col3" class="data row11 col3" >Dawn, Morning, Lunch, Afternoon, Night</td>
#     </tr>
#     <tr>
#       <th id="T_9506d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9506d_row12_col0" class="data row12 col0" >dia_sem</td>
#       <td id="T_9506d_row12_col1" class="data row12 col1" >category</td>
#       <td id="T_9506d_row12_col2" class="data row12 col2" >0</td>
#       <td id="T_9506d_row12_col3" class="data row12 col3" >Monday, Tuesday, Wednesday, Thursday, Friday</td>
#     </tr>
#     <tr>
#       <th id="T_9506d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9506d_row13_col0" class="data row13 col0" >curr_work</td>
#       <td id="T_9506d_row13_col1" class="data row13 col1" >int64</td>
#       <td id="T_9506d_row13_col2" class="data row13 col2" >0</td>
#       <td id="T_9506d_row13_col3" class="data row13 col3" >0, 1</td>
#     </tr>
#     <tr>
#       <th id="T_9506d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9506d_row14_col0" class="data row14 col0" >sector_comb</td>
#       <td id="T_9506d_row14_col1" class="data row14 col1" >object</td>
#       <td id="T_9506d_row14_col2" class="data row14 col2" >43516</td>
#       <td id="T_9506d_row14_col3" class="data row14 col3" >Services, Commerce, Industry, Construction, Public Administration, Agriculture</td>
#     </tr>
#     <tr>
#       <th id="T_9506d_level0_row15" class="row_heading level0 row15" >15</th>

# %% [markdown]
# ### Checking age intervals

# %%
pod_23_2["age"].value_counts(dropna=False)
# Out:
# age
# 30 to 59 years old       53588
# 16 to 29 years old       22793
# 60 years old or older    18304
# 15 years old or less     18185
# Name: count, dtype: int64

# %% [markdown]
# #### Under 16 and work

# %%
pod_23_3[pod_23_3["age"] == "15 years old or less"]["curr_work"].value_counts(dropna=False)
# Out:
# curr_work
# 0    18132
# 1       53
# Name: count, dtype: int64

# %% [markdown]
# ### Saving new dataset

# %%
pod_23_3.to_parquet("pod_23_3.parquet")
